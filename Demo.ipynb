# %%
# !pip uninstall felzenszwalb-segmentation -y
# Out:
# Found existing installation: felzenszwalb-segmentation 0.1.1
# Uninstalling felzenszwalb-segmentation-0.1.1:
#   Successfully uninstalled felzenszwalb-segmentation-0.1.1

# %%
import numpy as np
from glob import glob
from PIL import Image
from matplotlib import pyplot as plt
from felzenszwalb_segmentation import segment

# %%
image_files = glob('./assets/cat-1.jpg')
len(image_files)
# Out:
# 1

# %%
image = np.array(Image.open(image_files[0]))
segmented_image = segment(image, 0.2, 20, 20)
fig = plt.figure(figsize=(12, 12))
a = fig.add_subplot(1, 2, 1)
plt.imshow(image)
a = fig.add_subplot(1, 2, 2)
plt.imshow(segmented_image.astype(np.uint8))
plt.show()
